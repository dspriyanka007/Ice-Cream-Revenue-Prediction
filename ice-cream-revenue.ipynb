# %% [markdown]
# ## <h1 style='color:blue'>**ICE CREAM REVENUE PREDICTION** </h1>

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Read Data**

# %%
df = pd.read_csv('../input/ice-cream-revenue/IceCreamData.csv')

# %%
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
df.shape
# Out:
# (500, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %% [markdown]
# ### **Data Visualization**

# %%
sns.jointplot(x='Temperature', y='Revenue', data=df)

# %%
plt.scatter(df['Temperature'], df['Revenue'])
plt.show()

# %% [markdown]
# ### **Feature Selection**

# %%
x = df[['Temperature']]
y = df[['Revenue']]

# %% [markdown]
# ### **Split Dataset**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
print('Shape of train dataset :', x_train.shape, y_train.shape)
print('Shape of test dataset :', x_test.shape, y_test.shape)
# Out:
# Shape of train dataset : (400, 1) (400, 1)
# Shape of test dataset : (100, 1) (100, 1)

# %% [markdown]
# ### **Model Building**

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9837324255882577
